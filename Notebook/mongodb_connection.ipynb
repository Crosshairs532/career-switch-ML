# %%
from pymongo import MongoClient
import os 
from dotenv import load_dotenv
import pandas as pd

load_dotenv()
# Out:
# True

# %%
database_url=os.getenv('MONGODB_URI')

# %%
try:
    print("Connecting to Mongodb..")
    client = MongoClient(database_url)

    if client:
        print("Connected to mongodb", client)

except Exception as e:
    print("Errro in Connection...")
# Out:
# Connecting to Mongodb..
# Connected to mongodb MongoClient(host=['ac-7zxgzjo-shard-00-00.kdqr8aj.mongodb.net:27017', 'ac-7zxgzjo-shard-00-01.kdqr8aj.mongodb.net:27017', 'ac-7zxgzjo-shard-00-02.kdqr8aj.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='Cluster0', authsource='admin', replicaset='atlas-zul4nk-shard-0', tls=True)

# %%
dbname = client['CW']

# %%
collection = dbname['career_switch']

# %%
df = pd.read_csv('')

# %%
df_list = df.to_dict(orient='records')

# %%
try:
    print("inserting documents...")
    collection.insert_many(df_list)
except Exception as e: 
    print("Error while inserting..")
# Out:
# inserting documents...
